# %%
import pandas as pd

# %%
df = pd.read_csv("https://drive.usercontent.google.com/u/1/uc?id=1eNJlwU2nte6Nu2DodGYvbqQySLmWgU7X&export=download")
# Out:
# <ipython-input-2-719d32388d79>:1: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("https://drive.usercontent.google.com/u/1/uc?id=1eNJlwU2nte6Nu2DodGYvbqQySLmWgU7X&export=download")

# %%
df.drop(0, inplace=True)
df.head()
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 2  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category      commodity unit priceflag pricetype currency price  \
# 1  cereals and tubers           Rice   KG    actual    Retail      INR   8.0
# 2  miscellaneous food          Sugar   KG    actual    Retail      INR  13.5
# 3        oil and fats  Oil (mustard)   KG    actual    Retail      INR  31.0
# 4  cereals and tubers           Rice   KG    actual    Retail      INR   6.8
# 5  cereals and tubers          Wheat   KG    actual    Retail      INR   6.2
#
#   usdprice
# 1    0.255
# 2   0.4303
# 3    0.988
# 4   0.2167
# 5   0.1976

# %% [markdown]
# # 1. Split a column in Pandas dataframe and get part of it

# %%
d=df['usdprice'].str.split(".", expand=True)
d.head()
# Out:
#    0     1
# 1  0   255
# 2  0  4303
# 3  0   988
# 4  0  2167
# 5  0  1976

# %% [markdown]
# # 2. Return the Index label if some condition is satisfied over a column in Pandas Dataframe

# %%
def Labl(column):
  return df[df[column]=='Delhi'].index

print(Labl('admin1'))
# Out:
# Int64Index([     1,      2,      3,     31,     32,     33,     65,     66,
#                109,    110,
#             ...
#             165913, 165914, 165915, 165916, 165917, 165918, 165919, 165920,
#             165921, 165922],
#            dtype='int64', length=3531)

# %% [markdown]
# # 3. Drop rows from the dataframe based on certain condition applied on a column

# %%
df.drop(Labl('market'), inplace=True)
df
# Out:
#               date            admin1     admin2      market   latitude  \
# 4       1994-01-15           Gujarat  Ahmadabad   Ahmedabad  23.033333
# 5       1994-01-15           Gujarat  Ahmadabad   Ahmedabad  23.033333
# 6       1994-01-15           Gujarat  Ahmadabad   Ahmedabad  23.033333
# 7       1994-01-15           Gujarat  Ahmadabad   Ahmedabad  23.033333
# 8       1994-01-15  Himachal Pradesh     Shimla      Shimla  31.103333
# ...            ...               ...        ...         ...        ...
# 168491  2024-01-15         Rajasthan     Jaipur  North Zone  26.938848
# 168492  2024-01-15         Rajasthan     Jaipur  North Zone  26.938848
# 168493  2024-01-15         Rajasthan     Jaipur  North Zone  26.938848
# 168494  2024-01-15         Rajasthan     Jaipur  North Zone  26.938848
# 168495  2024-01-15         Rajasthan     Jaipur  North Zone  26.938848
#
#         longitude               category        commodity unit priceflag  \
# ...
